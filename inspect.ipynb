# %%
import pandas as pd

df = pd.read_parquet("data/hm_products.parquet")

# %%
row = df.iloc[0]

print("Product:", row["prod_name"])
print("Text:", row["text_to_embed"])
print("Dense dims:", len(row["dense_embedding"]))
print("Sparse terms:", len(row["sparse_indices"]))
print("Dense sample:", row["dense_embedding"][:5])
print("Sparse indices:", row["sparse_indices"][:10])
print("Sparse values:", row["sparse_values"][:10])
# Out:
# Product: Strap top
# Text: Strap top Vest top Garment Upper body Solid Black Dark Black Jersey Basic Ladieswear Ladieswear Womens Everyday Basics Jersey Basic Jersey top with narrow shoulder straps.
# Dense dims: 384
# Sparse terms: 77
# Dense sample: [np.float64(-0.04002443701028824), np.float64(0.06537477672100067), np.float64(-0.039091143757104874), np.float64(-0.05431661754846573), np.float64(0.04098440706729889)]
# Sparse indices: [np.int64(2007), np.int64(2303), np.int64(2304), np.int64(2308), np.int64(2316), np.int64(2327), np.int64(2417), np.int64(2450), np.int64(2601), np.int64(2630)]
# Sparse values: [np.float64(0.023138638585805893), np.float64(1.192923665046692), np.float64(1.5278069972991943), np.float64(1.1025447845458984), np.float64(0.17288726568222046), np.float64(1.6598107814788818), np.float64(0.7138957977294922), np.float64(0.45357251167297363), np.float64(1.0349204540252686), np.float64(0.5504095554351807)]
